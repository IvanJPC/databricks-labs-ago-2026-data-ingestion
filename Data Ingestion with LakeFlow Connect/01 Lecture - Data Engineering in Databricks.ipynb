# %% [markdown]
# ![DBAcademy](https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/databricks_academy.png)

# %% [markdown]
# # Lecture - Data Engineering in Databricks
#
# ## Overview
#
# This lecture introduces the fundamentals of data engineering in Databricks, focusing on how **LakeFlow Connect** simplifies and unifies data ingestion from diverse sources into the **Databricks Data Intelligence Platform**. You will learn about the **different ingestion methods** available through LakeFlow Connect, including batch, incremental batch, and streaming. The lecture also provides a review of **Delta Lake**, covering Delta table components, key features, and the Medallion Architecture for progressively refining data quality.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
#
# 1. **Describe the purpose and benefits of LakeFlow Connect** for scalable data ingestion into Databricks
# 2. **Identify the different types of connectors**, including Standard and Managed connectors
# 3. **Explain various data ingestion techniques** such as batch, incremental batch, and streaming
# 4. **Select the appropriate ingestion method** based on data and use case requirements
# 5. **Review the key benefits of Delta tables** and the Medallion Architecture for data management and analytics

# %% [markdown]
# ## A. Introduction to Data Engineering in Databricks

# %% [markdown]
# ### A1. Data Engineering Platform Overview
#
# Databricks offers LakeFlow, an end-to-end data engineering solution for delivering high-quality data for downstream analytics, AI, and operational applications.
#
# <div style="max-width:1000px;margin:0 auto;font-family:sans-serif;color:#0b2026;line-height:1.2;"><div style="display:flex;justify-content:center;position:relative;z-index:2;margin-bottom:-1px;"><div style="border:1px solid #FFD3CB;border-bottom:none;background:#fff;border-radius:10px 10px 0 0;padding:6px 22px;"><span style="font-size:18pt;font-weight:800;letter-spacing:-0.5px;">databricks</span> <span style="font-size:18pt;font-weight:800;color:#FF5F46;margin-left:6px;">LAKEFLOW</span></div></div><div style="border:1px solid #FFD3CB;border-radius:10px;padding:14px;"><div style="text-align:center;color:#FF5F46;font-weight:800;font-size:14pt;letter-spacing:0.5px;margin-bottom:12px;">UNIFIED DATA ENGINEERING FOR THE DATA INTELLIGENCE PLATFORM</div><div style="display:flex;gap:12px;margin-bottom:12px;flex-wrap:wrap;"><div style="flex:1;min-width:200px;border:1px solid #EEEDE9;border-radius:6px;overflow:hidden;box-shadow:0 1px 4px rgba(27,49,57,0.06);"><div style="background:#FF5F46;color:#fff;font-weight:800;font-size:14pt;text-align:center;letter-spacing:0.5px;min-height:56px;display:flex;align-items:center;justify-content:center;padding:8px 10px;">CONNECT</div><div style="padding:11px 14px;text-align:center;font-weight:700;font-size:14pt;">Efficient ingestion connectors</div></div><div style="flex:1;min-width:200px;border:1px solid #EEEDE9;border-radius:6px;overflow:hidden;box-shadow:0 1px 4px rgba(27,49,57,0.06);"><div style="background:#FF5F46;color:#fff;font-weight:800;font-size:14pt;text-align:center;letter-spacing:0.5px;min-height:56px;display:flex;align-items:center;justify-content:center;padding:8px 10px;">APACHE SPARK DECLARATIVE PIPELINES (SDP)</div><div style="padding:11px 14px;text-align:center;font-weight:700;font-size:14pt;">Accelerated ETL development</div></div><div style="flex:1;min-width:200px;border:1px solid #EEEDE9;border-radius:6px;overflow:hidden;box-shadow:0 1px 4px rgba(27,49,57,0.06);"><div style="background:#FF5F46;color:#fff;font-weight:800;font-size:14pt;text-align:center;letter-spacing:0.5px;min-height:56px;display:flex;align-items:center;justify-content:center;padding:8px 10px;">JOBS</div><div style="padding:11px 14px;text-align:center;font-weight:700;font-size:14pt;">Reliable orchestration for analytics and AI</div></div></div><div style="background:#FF5F46;color:#fff;border-radius:6px;text-align:center;padding:13px 14px;"><div style="font-weight:800;font-size:16pt;letter-spacing:0.5px;">INDUSTRY LEADING DATA PROCESSING ENGINE</div><div style="font-weight:700;font-size:14pt;margin-top:3px;">(Apache Spark + Structured Streaming)</div></div></div><div style="display:flex;margin-top:8px;border:1px solid #EEEDE9;border-radius:6px;overflow:hidden;"><div style="background:#618794;color:#fff;font-weight:800;font-size:14pt;letter-spacing:0.5px;padding:10px 14px;width:240px;display:flex;align-items:center;">UNIFIED GOVERNANCE</div><div style="flex:1;background:#fff;display:flex;align-items:center;justify-content:center;font-weight:800;font-size:14pt;padding:8px;">Unity Catalog</div></div><div style="display:flex;margin-top:6px;border:1px solid #EEEDE9;border-radius:6px;overflow:hidden;"><div style="background:#618794;color:#fff;font-weight:800;font-size:14pt;letter-spacing:0.5px;padding:10px 14px;width:240px;display:flex;align-items:center;">OPTIMIZED STORAGE</div><div style="flex:1;background:#fff;display:flex;align-items:center;justify-content:center;gap:24px;font-weight:800;font-size:14pt;padding:8px;flex-wrap:wrap;"><span>Delta Lake</span><span style="color:#DCE0E2;font-weight:400;">|</span><span>Parquet</span><span style="color:#DCE0E2;font-weight:400;">|</span><span>Iceberg</span></div></div></div>
#
# This course focuses on data ingestion with LakeFlow Connect into the Databricks Data Intelligence Platform.

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# LakeFlow provides a unified platform for data ingestion, transformation, and orchestration:
#
# - **LakeFlow Connect** — Efficient ingestion connectors for enterprise applications, databases, cloud storage, message buses, and local files
# - **Apache Spark™ Declarative Pipelines** — A framework for building batch and streaming data pipelines using SQL and Python
# - **LakeFlow Jobs** — Workflow automation that orchestrates data processing workloads and coordinates multiple tasks within complex workflows
#
# </details>

# %% [markdown]
# ## B. What Is LakeFlow Connect?
#
# LakeFlow Connect streamlines data ingestion with simple, efficient connectors that enable you to bring in data from files, cloud storage, databases, enterprise applications, and streaming sources directly into the Databricks Lakehouse — all within a unified, managed platform.

# %% [markdown]
# ### B1. Traditional Data Ingestion Challenges
#
# Traditionally, organizations resort to a patchwork of solutions for data ingestion when working with enterprise systems, cloud storage, and streaming.
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/traditional-data-ingestion-challenges.png"
#     alt="Traditional Data Ingestion Challenges"
#     style="width: 900px; max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# - Multiple data sources each require their own set of tools and solutions.
# - On-premises files, legacy systems, databases, cloud storage, SaaS applications, and real-time event streams all use different connectors.
# - A mix of third-party tools and in-house solutions creates complexity.
# - The result is increased operational overhead, inconsistent governance, and fragmented observability.
#
# </details>

# %% [markdown]
# ### B2. LakeFlow Connect: Unified Ingestion
#
# With LakeFlow Connect, you can build efficient ingestion pipelines entirely within Databricks. It provides simple setup and maintenance, along with unified orchestration, observability, and governance — all within the Databricks Data Intelligence Platform.
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/lakeflow-connect-unified-ingestion.png"
#     alt="LakeFlow Connect Unified Ingestion"
#     style="width: 900px; max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# ### B3. Key Benefits of LakeFlow Connect
#
# LakeFlow Connect provides built-in connectors for the Databricks Data Intelligence Platform to streamline data ingestion.
#
# <div style="text-align: center; margin: 32px 0 8px 0;">
#   <div style="display: inline-block; background: #0b2026; color: #F9F7F4;
#               font-size: 17px; font-weight: bold; letter-spacing: 0.5px;
#               padding: 12px 40px; border-radius: 8px;">
#     Key Benefits
#   </div>
#   <div style="width: 2px; height: 32px; background: #618794; margin: 0 auto;"></div>
# </div>
#
# <div style="display: flex; gap: 16px; margin: 0 0 32px 0;">
#
#   <div style="flex: 1; background: #F9F7F4; border-top: 4px solid #4299E0;
#               border-radius: 8px; padding: 22px 20px; text-align: center;
#               box-shadow: 0 2px 8px rgba(11,32,38,0.07);">
#     <div style="font-weight: bold; color: #0b2026; font-size: 16pt; margin-bottom: 8px;">
#       Managed and Efficient Solution
#     </div>
#     <div style="font-size: 14pt; color: #618794; line-height: 1.7;">
#       Lower costs and quicker time to value
#     </div>
#   </div>
#
#   <div style="flex: 1; background: #F9F7F4; border-top: 4px solid #00A972;
#               border-radius: 8px; padding: 22px 20px; text-align: center;
#               box-shadow: 0 2px 8px rgba(11,32,38,0.07);">
#     <div style="font-weight: bold; color: #0b2026; font-size: 16pt; margin-bottom: 8px;">
#       Self-Serve Interfaces for Every Practitioner
#     </div>
#     <div style="font-size: 14pt; color: #618794; line-height: 1.7;">
#       Democratized data with an accelerated rate of innovation
#     </div>
#   </div>
#
#   <div style="flex: 1; background: #F9F7F4; border-top: 4px solid #FF5F46;
#               border-radius: 8px; padding: 22px 20px; text-align: center;
#               box-shadow: 0 2px 8px rgba(11,32,38,0.07);">
#     <div style="font-weight: bold; color: #0b2026; font-size: 16pt; margin-bottom: 8px;">
#       Unified Observability and Governance
#     </div>
#     <div style="font-size: 14pt; color: #618794; line-height: 1.7;">
#       Secured and healthy pipelines and tables
#     </div>
#   </div>
#
# </div>

# %% [markdown]
# ### B4. LakeFlow Connect Connectors Overview
#
# LakeFlow Connect provides three categories of connectors, each designed for a different type of data source and ingestion pattern.
#
# <div style="max-width: 1100px; margin: 20px auto 0 auto; font-family: sans-serif; color: #0b2026;">
#
# <div style="display: flex; gap: 16px; align-items: stretch;">
#
#   <div style="flex: 1; border: 2px solid #FF5F46; border-radius: 10px; padding: 20px;">
#     <div style="text-align: center; margin-bottom: 12px;">
#       <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/cloud_upload.png" alt="Upload Files icon" style="max-height: 80px; max-width: 100px; width: auto; height: auto;">
#     </div>
#     <div style="font-size: 16pt; font-weight: 700; margin-bottom: 12px;">Upload Files</div>
#     <ul style="font-size: 14pt; line-height: 1.7; padding-left: 18px; margin: 0;">
#       <li>Upload local files to Databricks</li>
#       <li>Upload a file to a volume</li>
#       <li>Create a table from a local file</li>
#     </ul>
#   </div>
#
#   <div style="flex: 1; border: 2px solid #FF5F46; border-radius: 10px; padding: 20px;">
#     <div style="text-align: center; margin-bottom: 12px;">
#       <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/standard_connectors.png" alt="Standard Connectors icon" style="max-height: 80px; max-width: 100px; width: auto; height: auto;">
#     </div>
#     <div style="font-size: 16pt; font-weight: 700; margin-bottom: 12px;">Standard Connectors</div>
#     <div style="font-size: 14pt; line-height: 1.6;">
#       <strong>Supported Sources:</strong>
#       <ul style="padding-left: 18px; margin: 4px 0 10px;">
#         <li>Cloud Object Storage</li>
#         <li>Kafka</li>
#         <li>Other Sources</li>
#       </ul>
#       <strong>Ingestion Methods:</strong>
#       <ul style="padding-left: 18px; margin: 4px 0 0;">
#         <li>Batch</li>
#         <li>Incremental Batch</li>
#         <li>Streaming</li>
#       </ul>
#     </div>
#   </div>
#
#   <div style="flex: 1; border: 2px solid #FF5F46; border-radius: 10px; padding: 20px;">
#     <div style="text-align: center; margin-bottom: 12px;">
#       <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/manager_connectors.png" alt="Managed Connectors icon" style="max-height: 80px; max-width: 100px; width: auto; height: auto;">
#     </div>
#     <div style="font-size: 16pt; font-weight: 700; margin-bottom: 12px;">Managed Connectors</div>
#     <div style="font-size: 14pt; line-height: 1.6;">
#       Ingest data into the lakehouse from:
#       <ul style="padding-left: 18px; margin: 4px 0 10px;">
#         <li>Software as a Service (SaaS) applications</li>
#         <li>Databases</li>
#       </ul>
#       <ul style="padding-left: 18px; margin: 0;">
#         <li>Leverage efficient <strong>incremental reads and writes</strong></li>
#         <li>Faster, scalable, and more cost-efficient</li>
#       </ul>
#     </div>
#   </div>
#
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# - **Manual File Uploads** allow users to quickly upload local files into volumes or tables.
# - **Standard Connectors** enable ingestion from sources like cloud storage and Kafka using batch, incremental, or streaming modes.
# - **Managed Connectors** are designed for enterprise applications and databases, enabling scalable and efficient incremental data ingestion into the lakehouse.
#
# </details>

# %% [markdown]
# ## C. Ingestion Methods
#
# When ingesting data into Databricks using LakeFlow Connect Standard Connectors, you can choose from several ingestion methods.

# %% [markdown]
# ### C1. Batch, Incremental Batch, and Streaming Ingestion
#
# Select each tab to explore the three ingestion methods available in LakeFlow Connect.
#
# <div style="width: 100%; margin: auto; font-family: sans-serif;">
#
# <style>
# .four-grid {
#     display: flex;
#     flex-direction: column;
#     gap: 60px;
#     justify-content: center;
#     align-items: center;
# }
# .ing-box {
#     width: 80%;
#     min-height: 400px;
#     background: #F9F7F4;
#     border: none;
#     border-radius: 8px;
#     box-shadow: 0 2px 8px rgba(27,49,57,0.06);
#     overflow: hidden;
#     display: flex;
#     flex-direction: column;
#     gap: 12px;
#     padding: 20px;
#     text-align: center;
#     position: relative;
#     box-sizing: border-box;
# }
# .ing-box::before {
#     content: "";
#     position: absolute;
#     top: 0; left: 0;
#     width: 100%; height: 8px;
# }
# .ing-box.batch::before       { background: #2574B5; }
# .ing-box.incremental::before { background: #02A36F; }
# .ing-box.streaming::before   { background: #FE3722; }
#
# .ing-box-title { font-size: 16pt; font-weight: bold; text-align: center; }
# .ing-box-icon  { display: inline-flex; align-items: center; justify-content: center; gap: 8px; }
# .ing-box-icon img { width: 50px; height: auto; border-radius: 4px; background: transparent; mix-blend-mode: multiply;
# filter: contrast(1.15) brightness(1); }
# .ing-box-content {
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     gap: 24px;
#     width: 100%;
# }
# .ing-box-text {
#     font-size: 14pt;
#     max-width: 500px;
#     text-align: left;
#     line-height: 1.6;
# }
# .ing-box-text ul { text-align: left; padding-left: 18px; margin: 0 0 14px 0; }
# .ing-box-text li { margin-bottom: 10px; }
# .ing-box-text li:last-child { margin-bottom: 0; }
# .ing-example {
#     padding: 12px 14px;
#     border-radius: 8px;
#     font-size: 14pt;
#     line-height: 1.6;
#     font-weight: 400;
# }
# .batch .ing-example       { background: rgba(37,116,181,0.10); border-left: 4px solid #2574B5; }
# .incremental .ing-example { background: rgba(2,163,111,0.10);  border-left: 4px solid #02A36F; }
# .streaming .ing-example   { background: rgba(254,55,34,0.10);  border-left: 4px solid #FE3722; }
# </style>
#
# <!-- Tabs -->
# <div style="display: flex; border-bottom: 2px solid #EEEDE9; margin-bottom: 0;">
#   <button class="dbtab" onclick="showTab(1)" style="padding: 10px 18px; border: none; border-bottom: 3px solid #2574B5; background: none; font-size: 14pt; font-weight: bold; color: #2574B5; cursor: pointer; margin-bottom: -2px;">Batch Ingestion</button>
#   <button class="dbtab" onclick="showTab(2)" style="padding: 10px 18px; border: none; border-bottom: 3px solid transparent; background: none; font-size: 14pt; font-weight: bold; color: #888; cursor: pointer; margin-bottom: -2px;">Incremental Batch Ingestion</button>
#   <button class="dbtab" onclick="showTab(3)" style="padding: 10px 18px; border: none; border-bottom: 3px solid transparent; background: none; font-size: 14pt; font-weight: bold; color: #888; cursor: pointer; margin-bottom: -2px;">Streaming Ingestion</button>
# </div>
#
# <br>
#
# <!-- TAB 1 -->
# <div class="dbpanel" style="display: block;">
#   <div class="four-grid">
#     <div class="ing-box batch">
#       <div class="ing-box-title">
#         <div class="ing-box-icon">
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/batch.png" alt="Batch icon">
#           <span>Batch Ingestion</span>
#         </div>
#       </div>
#       <div class="ing-box-content">
#         <div>
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/batch_ingestion.png"
#                alt="Batch Ingestion diagram"
#                style="width: 500px; max-width: 100%; height: auto; background: transparent; mix-blend-mode: multiply; filter: contrast(1.15) brightness(1);">
#         </div>
#         <div class="ing-box-text">
#           <ul>
#             <li>Load data as <strong>batches of rows into Databricks</strong>, often based on a schedule</li>
#             <li>Traditional batch ingestion <strong>processes all records</strong> each time it runs</li>
#           </ul>
#           <div class="ing-example">
#             <strong>Common techniques include:</strong>
#             <ol>
#               <li>The SQL statement: <code>CREATE TABLE AS SELECT</code></li>
#               <li>The Python method: <code>spark.read.load()</code></li>
#             </ol>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <br>
#
# <!-- TAB 2 -->
# <div class="dbpanel" style="display: none;">
#   <div class="four-grid">
#     <div class="ing-box incremental">
#       <div class="ing-box-title">
#         <div class="ing-box-icon">
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/incremental.png" alt="Incremental icon">
#           <span>Incremental Batch Ingestion</span>
#         </div>
#       </div>
#       <div class="ing-box-content">
#         <div>
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/incremental_ingestion.png"
#                alt="Incremental Batch Ingestion diagram"
#                style="width: 500px; max-width: 100%; height: auto; background: transparent; mix-blend-mode: multiply; filter: contrast(1.15) brightness(1);">
#         </div>
#         <div class="ing-box-text">
#           <ul>
#             <li><strong>Only new data is ingested</strong> — previously loaded records are <strong>skipped automatically</strong></li>
#             <li>Provides <strong>faster</strong> and more <strong>resource-efficient</strong> ingestion by processing less data</li>
#           </ul>
#           <div class="ing-example">
#             <strong>Common techniques include:</strong>
#             <ol>
#               <li>The SQL statement: <code>COPY INTO</code></li>
#               <li>The Python method: <code>spark.readStream</code> (Auto Loader with a timed trigger)</li>
#               <li>Declarative Pipelines: <code>CREATE OR REFRESH STREAMING TABLE</code></li>
#             </ol>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <br>
#
# <!-- TAB 3 -->
# <div class="dbpanel" style="display: none;">
#   <div class="four-grid">
#     <div class="ing-box streaming">
#       <div class="ing-box-title">
#         <div class="ing-box-icon">
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/streaming.png" alt="Streaming icon">
#           <span>Streaming Ingestion</span>
#         </div>
#       </div>
#       <div class="ing-box-content">
#         <div>
#           <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/streaming_ingestion.png"
#                alt="Streaming Ingestion diagram"
#                style="width: 500px; max-width: 100%; height: auto; background: transparent; mix-blend-mode: multiply; filter: contrast(1.15) brightness(1);">
#         </div>
#         <div class="ing-box-text">
#           <ul>
#             <li><strong>Continuously load data</strong> rows or batches of data rows as they are generated, so you can query them as they <strong>arrive in near real-time</strong></li>
#             <li><strong>Micro-batch</strong> processes small batches at very <strong>short, frequent intervals</strong></li>
#           </ul>
#           <div class="ing-example">
#             <strong>Common techniques include:</strong>
#             <ol>
#               <li><code>spark.readStream</code> (Auto Loader with continuous trigger)</li>
#               <li>Declarative Pipelines (trigger mode continuous)</li>
#             </ol>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# </div>
#
# <script>
# function showTab(n) {
#   var tabs   = document.getElementsByClassName("dbtab");
#   var panels = document.getElementsByClassName("dbpanel");
#   var colors = ["#2574B5", "#02A36F", "#FE3722"];
#   for (var i = 0; i < tabs.length; i++) {
#     tabs[i].style.color        = "#888";
#     tabs[i].style.borderBottom = "3px solid transparent";
#     panels[i].style.display    = "none";
#   }
#   tabs[n-1].style.color        = colors[n-1];
#   tabs[n-1].style.borderBottom = "3px solid " + colors[n-1];
#   panels[n-1].style.display    = "block";
# }
# window.onload = function() { showTab(1); };
# </script>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# #### Batch Ingestion
# 1. Batch ingestion is well-suited for large volumes of historical data where real-time processing is not required.
# 2. It is typically simpler to implement and manage, making it a common choice for scheduled data pipelines.
#
# #### Incremental Batch Ingestion
# 1. Databricks supports both traditional batch ingestion and incremental batch ingestion options.
# 2. While traditional batch ingestion processes all records every time it runs, incremental batch ingestion automatically detects new records in the data source and skips records that have already been ingested.
#
# #### Streaming Ingestion
# 1. With streaming ingestion, data is continuously loaded as it is generated, allowing you to query it in near real-time. This method is ideal for loading streaming data from sources such as Apache Kafka, Amazon Kinesis, Google Pub/Sub, and Apache Pulsar.
# 2. Streaming ingestion processes data as it arrives, enabling low-latency analysis and immediate action. In contrast, micro-batch ingestion collects data over short, frequent intervals (seconds or minutes) and processes it in small batches — striking a balance between latency and system efficiency.
#
# </details>

# %% [markdown]
# ## D. Delta Lake Review
#
# Delta Lake delivers open, reliable, and scalable data management for the Lakehouse, empowering you to ingest data from external sources and efficiently manage it across **Bronze (raw)**, **Silver (cleaned)**, and **Gold (curated)** layers — all with full ACID transactions, time travel, schema enforcement, and support for both batch and streaming workloads.

# %% [markdown]
# ### D1. Ingesting Data Into Delta Lake
#
# The goal is to ingest files from **external data sources** like cloud object storage into **Delta Lake as Delta tables**.
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/delta-lake.png"
#     alt="Ingesting Data Into Delta Lake"
#     style="width: 900px; max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# Delta Lake is an open-source protocol for reading and writing files to cloud storage. Delta tables offer an open table format that supports the **Lakehouse architecture** and storage on AWS, Azure, and GCP cloud data lakes.
#
# </details>

# %% [markdown]
# ### D2. Delta Table Components Overview
#
# Within Delta Lake you will work with Delta tables. The diagram below shows how data is stored internally.
#
# <div style="display: flex; gap: 0; margin: 20px 0; align-items: stretch;">
#
#   <div style="flex: 1; background: #E8F5E9; border-top: 4px solid #388E3C; border-radius: 12px 0 0 12px; padding: 24px;">
#     <div style="font-size: 14pt; color: #1B5E20; margin-bottom: 16px; line-height: 1.7;">
#       <ol>
#         <li>Data is stored in Delta tables.</li>
#         <li>Internally, these tables store data as files within a folder directory.</li>
#       </ol>
#     </div>
#     <div style="text-align: center;">
#       <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/delta-table.png"
#            alt="Delta table folder structure"
#            style="max-width: 90%; height: auto; border-radius: 6px; border: 1px solid #e0e0e0;">
#       <p style="margin: 12px 0 0 0; font-size: 13px; color: #666; font-style: italic;">Delta tables store data as files within a folder directory.</p>
#     </div>
#   </div>
#
#   <div style="display: flex; align-items: center; justify-content: center; padding: 0 20px; background: #F8F9FA; border-top: 1px solid #E0E0E0; border-bottom: 1px solid #E0E0E0;">
#     <div style="font-size: 24px; color: #999; font-weight: 300;">→</div>
#   </div>
#
#   <div style="flex: 1; background: #E3F2FD; border-top: 4px solid #1976D2; border-radius: 0 12px 12px 0; padding: 24px;">
#     <div style="font-size: 14pt; color: #0D47A1; margin-bottom: 16px; line-height: 1.7;">
#       <ol>
#         <li>Data is stored as Parquet files in the directory.</li>
#         <li>Delta Lake adds JSON-based Delta logs alongside these files.</li>
#         <li>Delta logs track transactions and table versions.</li>
#       </ol>
#     </div>
#     <div style="text-align: center;">
#       <img src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/delta-lake-table.png"
#            alt="Delta Lake Parquet files and transaction logs"
#            style="max-width: 100%; height: auto; border-radius: 6px; border: 1px solid #e0e0e0;">
#       <p style="margin: 12px 0 0 0; font-size: 13px; color: #666; font-style: italic;">Delta Lake stores data as Parquet files and maintains transaction logs.</p>
#     </div>
#   </div>
#
# </div>

# %% [markdown]
# ### D3. Delta Table Key Features
#
# Delta tables provide a variety of key features in a cloud data lake:
#
# <div class="mermaid">
# flowchart LR
#     acid["<img src='https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/ACID.png'/><br/><b style='font-size:15px;'>ACID Transactions</b><br/><br/><b>A</b>tomicity<br><b>C</b>onsistency<br><b>I</b>solation<br><b>D</b>urability<br/>For all operations, allowing <b>multiple users to read and write data</b> concurrently without conflicts."]
#     dml["<img src='https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/DML.png'/><br/><b style='font-size:15px;'>Data Manipulation Language (DML)</b><br/><br/>Supports DML operations such as <b>INSERT, UPDATE, DELETE, and MERGE</b>, enabling flexible data management."]
#     tt["<img src='https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/time-travel.png'/><br/><b style='font-size:15px;'>Time Travel</b><br/><br/>Allows users to <b>query</b> and <b>revert</b> to previous versions of data, facilitating <b>auditing and recovery</b>."]
#     schema["<img src='https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/schema.png'/><br/><b style='font-size:15px;'>Schema Evolution and Enforcement</b><br/><br/>Enforces a defined <b>schema for data integrity</b> while allowing schema evolution, enabling structural changes without breaking existing workflows."]
#     mm["<img src='https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/many-more.png'/><br/><b style='font-size:15px;'>Many More!</b><br/><br/>Provides additional features including unified batch and streaming processing, performance optimization, and scalability."]
#     acid --- dml --- tt --- schema --- mm
# classDef process fill:#FFFFFF,color:#0b2026,stroke:#FF5F46,stroke-width:3px
# class dml,tt,schema process
# classDef endpoint fill:#FFFFFF,color:#0b2026,stroke:#1B5162,stroke-width:3px
# class acid,mm endpoint
# linkStyle 0 stroke:#618794,stroke-width:3px
# linkStyle 1 stroke:#618794,stroke-width:3px
# linkStyle 2 stroke:#618794,stroke-width:3px
# linkStyle 3 stroke:#618794,stroke-width:3px
# </div>
#
# <script type="module">
# import mermaid from "https://cdn.jsdelivr.net/npm/mermaid@11/dist/mermaid.esm.min.mjs";
# mermaid.initialize({
#   startOnLoad: true,
#   theme: "base",
#   htmlLabels: true,
#   flowchart: {
#     htmlLabels: true,
#     curve: "basis",
#     nodeSpacing: 30,
#     rankSpacing: 40,
#     padding: 12
#   },
#   themeVariables: {
#     background: "#FFFFFF",
#     primaryColor: "#FFFFFF",
#     primaryTextColor: "#0b2026",
#     primaryBorderColor: "#1B5162",
#     lineColor: "#618794",
#     secondaryColor: "#FFFFFF",
#     tertiaryColor: "#FFFFFF",
#     edgeLabelBackground: "#FFFFFF",
#     fontFamily: "Arial, sans-serif"
#   }
# });
# </script>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# The **transaction log** enables key functionality in Delta tables by maintaining table states.
#
# - It records every **insert, update, and delete** as transactions, ensuring the table stays consistent and up to date.
# - This allows for **reliable data views and time travel**, making it easy to access previous versions of data.
#
# Traditionally, modifying data in a data lake required **manually recreating files and tracking changes**, which was complex and inefficient.
#
# - With Delta Lake, data modifications are **simpler, faster, and more efficient to manage**.
#
# </details>

# %% [markdown]
# ## E. Medallion Architecture Review

# %% [markdown]
# ### E1. Overview
#
# The Medallion Architecture is a layered data design pattern that progressively improves data quality as it moves through Bronze, Silver, and Gold layers.
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_lakeflow_connect/medallion-architecture.png"
#     alt="Medallion Architecture Review"
#     style="width: 900px; max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# ### E2. Medallion Architecture Steps in Detail
#
# Each step in the Medallion Architecture builds on the previous one, refining data quality and usability.
#
# <div class="mermaid">
# flowchart LR
#     S0["<b>Step 1</b><br/><b>Ingest Data</b><br/>Data is ingested into Delta Lake using batch, streaming, or both methods.<br/>This marks the starting point for processing in Databricks."]
#     S1["<b>Step 2</b><br/><b>Process and Improve Data Quality</b><br/>Data is incrementally refined as it moves through layers.<br/>Each stage improves structure, quality, and usability."]
#     S2["<b>Step 3</b><br/><b>Bronze Layer (Raw Data)</b><br/>Stores raw, unprocessed data from multiple sources.<br/>Acts as the foundation for all downstream processing."]
#     S3["<b>Step 4</b><br/><b>Silver Layer (Cleaned Data)</b><br/>Data is cleaned, transformed, and enriched.<br/>Produces structured and analysis-ready datasets."]
#     S4["<b>Step 5</b><br/><b>Gold Layer (Business-Ready Data)</b><br/>Contains curated and aggregated data.<br/>Optimized for reporting, BI, and advanced analytics."]
#     S0 --> S1 --> S2 --> S3 --> S4
#     style S0 fill:#E8F4FD,stroke:#5A9BD5,stroke-width:2px
#     style S1 fill:#E5F5F3,stroke:#5BA8A0,stroke-width:2px
#     style S2 fill:#EFF6E8,stroke:#7CB342,stroke-width:2px
#     style S3 fill:#FFF8E6,stroke:#E6AC00,stroke-width:2px
#     style S4 fill:#FFEFE8,stroke:#E86A4A,stroke-width:2px
# </div>
#
# <script type="module">
# import mermaid from "https://cdn.jsdelivr.net/npm/mermaid@11/dist/mermaid.esm.min.mjs";
# mermaid.initialize({ startOnLoad: true, theme: "default" });
# </script>

# %% [markdown]
# ## F. Conclusion
#
# In this lecture, you learned the fundamentals of data engineering in Databricks with a focus on LakeFlow Connect and Delta Lake:
#
# 1. **LakeFlow Connect** is the ingestion layer within the Databricks Data Intelligence Platform that replaces the traditional patchwork of ingestion tools with a unified, managed solution.
# 2. LakeFlow Connect provides three types of connectors: **Upload Files**, **Standard Connectors**, and **Managed Connectors**, each designed for different data source types.
# 3. Three ingestion methods are available: **Batch** (processes all records), **Incremental Batch** (processes only new records), and **Streaming** (continuous, near real-time ingestion).
# 4. **Delta Lake** is an open-source protocol that stores data as Parquet files with transaction logs, enabling ACID transactions, time travel, DML support, and schema enforcement.
# 5. The **Medallion Architecture** (Bronze, Silver, Gold) progressively improves data quality as it moves through each layer.
#
# ### Next Steps
#
# In the next section, you will begin working hands-on with LakeFlow Connect to ingest data into Delta Lake tables.

# %% [markdown]
# &copy; <span id="dbx-year"></span> Databricks, Inc. All rights reserved.
# Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/>
# <a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> |
# <a href="https://help.databricks.com/" target="_blank">Support</a>
# <script>
#   document.getElementById("dbx-year").textContent = new Date().getFullYear();
# </script>
