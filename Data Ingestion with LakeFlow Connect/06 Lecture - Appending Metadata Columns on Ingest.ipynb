# %% [markdown]
# ![DBAcademy](https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/icons/databricks_academy.png)

# %% [markdown]
# # Lecture - Appending Metadata Columns on Ingest
#
# ## Overview
#
# In this lecture, you will learn how metadata columns such as source file name and modification time can be appended during data ingestion from cloud storage using the <code>_metadata</code> column, enabling essential context to be captured for each row during table creation in the Lakehouse.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
#
# 1. **Explain the purpose of metadata columns** and why they are valuable during data ingestion
# 2. **Use the `_metadata` column to append file-level metadata** such as file name and modification time during table creation
# 3. **Identify common `_metadata` fields** including `_metadata.file_name` and `_metadata.file_modification_time`

# %% [markdown]
# ## A. Adding a Metadata Column
#
# You can append metadata column information from input data source files when creating a table.
#
# ##### Click each step below to explore how a metadata column is added in Bronze table.
#
# <div style="width:100%;font-family:'Segoe UI',sans-serif;max-width:1000px;margin:0 auto;">
#
# <style>
# .meta-tabs{
#  display:flex;
#  align-items:center;
#  justify-content:center;
#  gap:6px;
#  flex-wrap:nowrap;
#  margin-bottom:8px
# }
# .meta-tab{
#  width:170px;background:#F9F7F4;border:1.5px solid #e8e5e0;border-radius:8px;
#  padding:8px 8px 7px;cursor:pointer;transition:.2s;box-sizing:border-box
# }
# .meta-tab:hover{box-shadow:0 3px 10px rgba(0,0,0,.08)}
# .meta-num{
#  width:24px;height:24px;border-radius:50%;display:flex;align-items:center;justify-content:center;
#  color:#fff;font-weight:800;font-size:11px;margin:0 auto 5px
# }
# .meta-tab-title{font-size:10.5pt;font-weight:700;color:#1b3139;text-align:center;line-height:1.2}
# .meta-tab-sub{font-size:8.5pt;color:#7a7974;text-align:center;margin-top:2px;line-height:1.25}
#
# .meta-arrow-connector{
#  width:18px;
#  height:0;
#  border-top:2px solid #90A5B1;
#  position:relative;
#  flex-shrink:0;
# }
# .meta-arrow-connector::after{
#  content:"";
#  position:absolute;
#  right:-1px;
#  top:-5px;
#  border-top:4px solid transparent;
#  border-bottom:4px solid transparent;
#  border-left:6px solid #90A5B1;
# }
#
# .meta-panel{
#  display:none;background:#F9F7F4;border:1.5px solid #e8e5e0;border-radius:10px;
#  padding:12px 14px;animation:fadeIn .2s ease
# }
# @keyframes fadeIn{from{opacity:0;transform:translateY(-4px)}to{opacity:1;transform:translateY(0)}}
#
# input[name="meta-step"]{display:none}
# #ms1:checked ~ .meta-tabs label[for="ms1"],
# #ms2:checked ~ .meta-tabs label[for="ms2"],
# #ms3:checked ~ .meta-tabs label[for="ms3"],
# #ms4:checked ~ .meta-tabs label[for="ms4"]{
#  border-color:var(--accent); box-shadow:0 3px 12px rgba(0,0,0,.10)
# }
# #ms1:checked ~ .meta-panels .p1,
# #ms2:checked ~ .meta-panels .p2,
# #ms3:checked ~ .meta-panels .p3,
# #ms4:checked ~ .meta-panels .p4{display:block}
#
# .meta-desc{font-size:10pt;color:#3a3a3a;line-height:1.5;margin:0}
# .meta-tags{display:flex;gap:6px;flex-wrap:wrap;margin-top:8px}
# .meta-tag{padding:2px 8px;border-radius:999px;font-size:8pt;font-weight:600;color:#fff}
# .meta-diag{display:flex;align-items:center;gap:10px;margin-top:10px;flex-wrap:wrap}
# .meta-box{
#  background:#fff;border-radius:8px;border:1.5px solid #e0ddd8;padding:10px 12px;min-width:150px;flex:1
# }
# .meta-label{
#  font-size:8pt;font-weight:700;color:#7a7974;text-transform:uppercase;letter-spacing:.05em;margin-bottom:6px
# }
# .meta-table{width:100%;border-collapse:collapse;font-size:9pt}
# .meta-table th{padding:5px 8px;text-align:left;color:#fff;font-weight:700;font-size:8pt}
# .meta-table td{padding:5px 8px;color:#1b3139;border-bottom:1px solid #f0edea;font-size:8pt}
# .meta-table tr:last-child td{border-bottom:none;color:#aaa}
# .meta-arrow{display:flex;flex-direction:column;align-items:center;gap:2px;color:#2574B5;font-size:8pt;font-weight:700}
# .meta-arrow-svg{width:32px;height:16px}
# .meta-green{background:#02A36F !important}
# .meta-callouts{display:flex;gap:8px;flex-wrap:wrap;margin-top:10px}
# .meta-callout{
#  flex:1;min-width:180px;padding:8px 10px;background:rgba(2,163,111,.08);
#  border-left:4px solid #02A36F;border-radius:6px;font-size:8.5pt;line-height:1.35
# }
#
# /* Image highlight area */
# .meta-figure-wrap{
#  position:relative;
#  width:720px;
#  max-width:100%;
#  margin:10px auto 0 auto;
#  overflow:hidden;
#  border-radius:8px;
# }
# .meta-figure-wrap img{
#  width:100%;
#  height:auto;
#  display:block;
#  transition:transform .3s ease;
# }
# .meta-highlight{
#  position:absolute;
#  border:3px solid #FF3B30;
#  border-radius:8px;
#  box-shadow:0 0 0 9999px rgba(255,255,255,0.08);
#  opacity:0;
#  transition:opacity .25s ease;
#  pointer-events:none;
# }
# .meta-h1{ left:2%; top:38%; width:23%; height:33%; }
# .meta-h2{ left:3%; top:3%; width:75%; height:30%; }
# .meta-h3{ left:70%; top:35%; width:28%; height:38%; }
# .meta-h4{ left:35%; top:36%; width:63%; height:59%; }
#
# #ms1:checked ~ .meta-figure-wrap .meta-h1,
# #ms2:checked ~ .meta-figure-wrap .meta-h2,
# #ms3:checked ~ .meta-figure-wrap .meta-h3,
# #ms4:checked ~ .meta-figure-wrap .meta-h4{
#  opacity:1;
# }
#
# #ms1:checked ~ .meta-figure-wrap img,
# #ms2:checked ~ .meta-figure-wrap img,
# #ms3:checked ~ .meta-figure-wrap img,
# #ms4:checked ~ .meta-figure-wrap img{transform:scale(1.01);}
#
# @media (max-width:900px){
#  .meta-arrow-connector{display:none}
#  .meta-tabs{flex-wrap:wrap}
#  .meta-tab{width:calc(50% - 6px)}
# }
# </style>
#
# <input type="radio" name="meta-step" id="ms1" checked>
# <input type="radio" name="meta-step" id="ms2">
# <input type="radio" name="meta-step" id="ms3">
# <input type="radio" name="meta-step" id="ms4">
#
# <div class="meta-figure-wrap">
#  <img
#  src="https://files.training.databricks.com/binder/prod_main/data-ingestion-with-lakeflow-connect-en_us-3.1.1/images/20260731T171356Z/Data Ingestion with LakeFlow Connect/Includes/images/lecture_append_metadata_column/adding-metadata-column-example.png"
#  alt="Adding Metadata Column">
#  <div class="meta-highlight meta-h1"></div>
#  <div class="meta-highlight meta-h2"></div>
#  <div class="meta-highlight meta-h3"></div>
#  <div class="meta-highlight meta-h4"></div>
# </div>
# <br>
#
# <div class="meta-tabs">
#  <label class="meta-tab" for="ms1" style="--accent:#2574B5;">
#   <div class="meta-num" style="background:#2574B5;">1</div>
#   <div class="meta-tab-title">Raw Files</div>
#   <div class="meta-tab-sub">CSV · TXT · JSON · other formats</div>
#  </label>
#  <div class="meta-arrow-connector"></div>
#  <label class="meta-tab" for="ms2" style="--accent:#1b7fb0;">
#   <div class="meta-num" style="background:#1b7fb0;">2</div>
#   <div class="meta-tab-title">Create a Delta Table</div>
#   <div class="meta-tab-sub">Ingest raw files into Bronze</div>
#  </label>
#  <div class="meta-arrow-connector"></div>
#  <label class="meta-tab" for="ms3" style="--accent:#02A36F;">
#   <div class="meta-num" style="background:#02A36F;">3</div>
#   <div class="meta-tab-title">Metadata Columns</div>
#   <div class="meta-tab-sub">Added from the ingestion source</div>
#  </label>
#  <div class="meta-arrow-connector"></div>
#  <label class="meta-tab" for="ms4" style="--accent:#1C3037;">
#   <div class="meta-num" style="background:#1C3037;">4</div>
#   <div class="meta-tab-title">Bronze Table</div>
#   <div class="meta-tab-sub">Original columns plus metadata columns</div>
#  </label>
# </div>
# <div class="meta-panels">
#  <div class="meta-panel p1">
#   <p class="meta-desc">
#    Suppose your cloud storage location contains a set of raw files. These could be CSV, TXT, JSON, or other formats.
#   </p>
#   <div class="meta-tags">
#    <span class="meta-tag" style="background:#2574B5;">CSV</span>
#    <span class="meta-tag" style="background:#2574B5;">TXT</span>
#    <span class="meta-tag" style="background:#2574B5;">JSON</span>
#   </div>
#   <div class="meta-diag">
#    <div class="meta-box" style="max-width:320px">
#     <div class="meta-label">raw_file</div>
#     <table class="meta-table">
#      <thead>
#       <tr style="background:#2c5f7c;"><th>users</th><th>unix_ts</th></tr>
#      </thead>
#      <tbody>
#       <tr><td>peter</td><td>1592187804331222</td></tr>
#       <tr><td>zebi</td><td>1592200952155132</td></tr>
#       <tr><td>…</td><td>…</td></tr>
#      </tbody>
#     </table>
#    </div>
#   </div>
#  </div>
#  <div class="meta-panel p2">
#   <p class="meta-desc">
#    You want to ingest those files into a bronze-level table.
#   </p>
#  </div>
#  <div class="meta-panel p3">
#   <p class="meta-desc">
#    As part of that ingestion, you may want to add specific metadata columns to each row in the table.
#    These columns can include information from the ingestion source, such as:
#   </p>
#   <div class="meta-tags">
#    <span class="meta-tag" style="background:#02A36F;">The last modification time of the file the row originated from</span>
#    <span class="meta-tag" style="background:#02A36F;">The source file name</span>
#   </div>
#  </div>
#  <div class="meta-panel p4">
#   <div class="meta-diag">
#    <div class="meta-box" style="min-width:140px;">
#     <div class="meta-label">raw_file</div>
#     <table class="meta-table">
#      <thead>
#       <tr style="background:#2c5f7c;"><th>users</th><th>unix_ts</th></tr>
#      </thead>
#      <tbody>
#       <tr><td>peter</td><td>1592187804331222</td></tr>
#       <tr><td>zebi</td><td>1592200952155132</td></tr>
#       <tr><td>…</td><td>…</td></tr>
#      </tbody>
#     </table>
#    </div>
#    <div class="meta-arrow">
#     <svg class="meta-arrow-svg" viewBox="0 0 50 20" fill="none">
#      <path d="M2 10 H42 M36 4 L48 10 L36 16" stroke="#2574B5" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round"/>
#     </svg>
#     <span style="font-size:7.5pt;">Create a Delta Table</span>
#    </div>
#    <div class="meta-box" style="flex:2;">
#     <div class="meta-label">Bronze Table</div>
#     <table class="meta-table">
#      <thead>
#       <tr>
#        <th style="background:#2c5f7c;">users</th>
#        <th style="background:#2c5f7c;">unix_ts</th>
#        <th class="meta-green">last_mod_time</th>
#        <th class="meta-green">source</th>
#       </tr>
#      </thead>
#      <tbody>
#       <tr>
#        <td>peter</td>
#        <td>1592187804331222</td>
#        <td style="background:rgba(2,163,111,.08);">2024-10-01T18:04…</td>
#        <td style="background:rgba(2,163,111,.08);">raw_file</td>
#       </tr>
#       <tr>
#        <td>zebi</td>
#        <td>1592200952155132</td>
#        <td style="background:rgba(2,163,111,.08);">2024-10-01T18:04…</td>
#        <td style="background:rgba(2,163,111,.08);">raw_file</td>
#       </tr>
#       <tr>
#        <td>…</td>
#        <td>…</td>
#        <td style="background:rgba(2,163,111,.08);">…</td>
#        <td style="background:rgba(2,163,111,.08);">…</td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#   </div>
#   <div class="meta-callouts">
#    <div class="meta-callout">
#     <strong>last_mod_time</strong><br>
#     Add the last file modification time
#    </div>
#    <div class="meta-callout">
#     <strong>source</strong><br>
#     Add the source file name
#    </div>
#   </div>
#   <p class="meta-desc" style="margin-top:10px;">
#    This helps preserve important context about the data’s origin, which can be valuable for auditing, lineage, and debugging purposes.
#   </p>
#  </div>
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# For example, suppose your cloud storage location contains <strong>a set of raw files</strong> (CSV, TXT, JSON, or other formats) and you want to ingest those files into a <strong>bronze-level table</strong>.
#
# As part of that ingestion, you may want to add specific metadata columns to each row in the table. These columns can include information from the ingestion source, such as:
#
# - The **last modification time** of the file the row originated from
# - The **source file name**
#
# This helps preserve important context about the data's origin, which can be valuable for auditing, lineage, and debugging purposes.
#
# </details>

# %% [markdown]
# ## B. Common File Metadata Fields
#
# To add metadata columns during ingestion, you can use the special `_metadata` column. This is a hidden column that is available for all input file formats.

# %% [markdown]
# <div style="max-width: 700px; margin: 0 auto; font-family: sans-serif; color: #0b2026;">
#
# <div style="display: flex; flex-direction: column; gap: 24px;">
#
#   <!-- file_modification_time -->
#   <div>
#     <div style="font-size: 14pt; margin-bottom: 8px;"><strong>Add last file modification timestamp</strong></div>
#     <div style="display: flex; align-items: center; gap: 14px;">
#       <div style="display: flex; align-items: center; gap: 4px;">
#         <div style="background: #FFAB00; color: white; border-radius: 4px; padding: 4px 10px; font-family: monospace; font-size: 13pt; font-weight: 600;">_metadata</div>
#         <div style="font-family: monospace; font-size: 12pt;">.file_modification_time</div>
#       </div>
#       <div style="font-size: 24pt; color: #00A972;"> > </div>
#       <div style="border: 2px solid #EEEDE9; border-radius: 6px; padding: 8px 14px; font-family: monospace; font-size: 12pt;">
#         2024-10-07T18:04:42.885+00:00
#       </div>
#     </div>
#   </div>
#
#   <!-- file_name -->
#   <div>
#     <div style="font-size: 14pt; margin-bottom: 8px;"><strong>Add input file name</strong></div>
#     <div style="display: flex; align-items: center; gap: 14px;">
#       <div style="display: flex; align-items: center; gap: 4px;">
#         <div style="background: #FFAB00; color: white; border-radius: 4px; padding: 4px 10px; font-family: monospace; font-size: 13pt; font-weight: 600;">_metadata</div>
#         <div style="font-family: monospace; font-size: 12pt;">.file_name</div>
#       </div>
#       <div style="font-size: 24pt; color: #00A972;"> > </div>
#       <div style="border: 2px solid #EEEDE9; border-radius: 6px; padding: 8px 14px; font-family: monospace; font-size: 12pt;">
#         part-00002-7573-1-c000.file_name
#       </div>
#     </div>
#   </div>
#
# </div>
# </div>

# %% [markdown]
# ##### Documentation
#
# - <a href="https://docs.databricks.com/aws/en/ingestion/file-metadata-column" style="color:#1976D2;">File Metadata Column</a>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# To include the <code>_metadata</code> column in the returned DataFrame, you must explicitly select it in your read query when specifying the source.
#
# The <code>_metadata</code> column contains a variety of useful fields. Two common fields include:
# <ol>
# <li><code>_metadata.file_modification_time</code> – provides the last modification timestamp of the input file</li>
# <li><code>_metadata.file_name</code> – returns the name of the source file for each row</li>
# </ol>
#
# </details>

# %% [markdown]
# ## C. Conclusion
#
# In this lecture, you learned how to append metadata columns from input source files during data ingestion:
#
# - **Metadata columns** preserve context about data origin, which is valuable for auditing, lineage, and debugging.
# - The special **`_metadata` column** is a hidden column available for all input file formats. You must explicitly select it in your read query.
# - Two commonly used fields:
#   - **`_metadata.file_modification_time`**: The last modification timestamp of the input file
#   - **`_metadata.file_name`**: The name of the source file for each row
#
# ### Next Steps
#
# In the next section, you will work hands-on with metadata columns to enrich your ingested data.

# %% [markdown]
# &copy; <span id="dbx-year"></span> Databricks, Inc. All rights reserved.
# Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/>
# <a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> |
# <a href="https://help.databricks.com/" target="_blank">Support</a>
# <script>
#   document.getElementById("dbx-year").textContent = new Date().getFullYear();
# </script>
